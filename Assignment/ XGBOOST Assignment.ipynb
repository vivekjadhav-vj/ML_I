# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from xgboost.sklearn import XGBClassifier

# %%
cols=["age","workclass","fnlwgt","education","education-num","marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week","native-country","wage_class"]

train_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',names=cols, header = None)

train_set.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country wage_class
# 0          2174             0              40   United-States      <=50K
# 1             0             0              13   United-States      <=50K
# 2             0             0              40   United-States      <=50K
# 3             0             0              40   United-States      <=50K
# 4             0             0              40            Cuba      <=50K

# %%
test_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test', skiprows = 1,names=cols, header = None)
test_set.head()
# Out:
#    age   workclass  fnlwgt      education  education-num       marital-status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   18           ?  103497   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country wage_class
# 0             0              40   United-States     <=50K.
# 1             0              50   United-States     <=50K.
# 2             0              40   United-States      >50K.
# 3             0              40   United-States      >50K.
# 4             0              30   United-States     <=50K.

# %%
train_set.isnull().sum()
   # no null values in any frame
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# wage_class        0
# dtype: int64

# %%
train_set.hist(figsize=(10,10))
plt.show()

# %%
train_set.dtypes  
#only 6 features(out of 14 are numeric)
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# wage_class        object
# dtype: object

# %%
for feature in cols:
    if train_set[feature].dtype == 'object':
        
        print('_'*10,feature, end=" ",)
        print('_'*10)
        print(train_set[feature].value_counts())
# Out:
# __________ workclass __________
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64
# __________ education __________
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64
# __________ marital-status __________
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64
# __________ occupation __________
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64
# __________ relationship __________
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: relationship, dtype: int64
# __________ race __________
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64
# __________ sex __________
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64
# __________ native-country __________
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: native-country, dtype: int64
# __________ wage_class __________
#  <=50K    24720
#  >50K      7841
# Name: wage_class, dtype: int64

# %%
train_set.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'wage_class'],
#       dtype='object')

# %%
import re
train_set.rename(columns=lambda name: re.sub(r"\-",'_',name), inplace=True)

# %%
filter1 = train_set["workclass"]=="?"
#index= train_set.where(filter1).index
index = train_set[train_set["native_country"]== ' ?'].index
#index.value_counts()  # to display all the indexes having value '?'
index.value_counts().sum()  # sum of those indexes 
# type(index)
# Out:
# 583

# %%
#now apply the filter for the '?' value in those above 3 columns

indexes_list = [] # will contain three index series of desired syntexes
def filter_questionMark(l):
    
    for item in l:
        print('_'*10,item, '_'*10)
        index = train_set[train_set[item]== ' ?'].index
        indexes_list.append(index)
        #index.value_counts()  # to display all the indexes having value '?'
        print("Total `?` in {0}: {1}".format(item, index.value_counts().sum()))  # sum of those indexes 
        print("Total % of `?` in {0}: {1}".format(item, round((index.value_counts().sum()/train_set.shape[0])*100,2)))
        
filter2= ['workclass','occupation', 'native_country']
filter_questionMark(filter2)
# Out:
# __________ workclass __________
# Total `?` in workclass: 1836
# Total % of `?` in workclass: 5.64
# __________ occupation __________
# Total `?` in occupation: 1843
# Total % of `?` in occupation: 5.66
# __________ native_country __________
# Total `?` in native_country: 583
# Total % of `?` in native_country: 1.79

# %% [markdown]
# Observation: Max % of having ? is 5.66 we can drop and can check how much it is affedting our data

# %%
print("Original Shape of Train Set:", train_set.shape)
print("Rows in Train Set:", train_set.shape[0])
# Out:
# Original Shape of Train Set: (32561, 15)
# Rows in Train Set: 32561

# %%
print('\n Drowping `?` indexes from `workclass` featutre....')
train_set= train_set.drop(index)
print("Total New rows:",train_set.shape[0])
# Out:
#  Drowping `?` indexes from `workclass` featutre....
# Total New rows: 31978

# %%
df1 = train_set.copy()

objectFeature = []
for i in list(df1.columns):
    if (df1[i].dtypes == 'object'):
        objectFeature.append(i)
        

df1=pd.get_dummies(df1[objectFeature[:-1]])

# %%
intFeature = []
for i in list(train_set.columns):
    if (train_set[i].dtypes == 'int64'):
        intFeature.append(i)

df2 = train_set[intFeature]

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (31978, 101)
# (31978, 6)

# %%
X_train = pd.concat([df1, df2], axis=1)
X_train.shape
# Out:
# (31978, 107)

# %%
y=train_set[objectFeature[-1]]

# %% [markdown]
# #### Using LabelEncoder over the target variable

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
# le.fit(y)
# le.classes_   # will display only two classes---> array([' <=50K', ' >50K'], dtype=object)y_train
y_train=le.fit_transform(y)

# %% [markdown]
# #### Applying XGB

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
train_x,test_x,train_y,test_y =train_test_split(X_train, y_train, test_size=.25)

# %%
# fit model no training data
model = XGBClassifier(objective='binary:logistic')
model.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# cheking training accuracy
y_pred = model.predict(train_x)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(train_y,predictions)
accuracy
# Out:
# 0.904724179627236

# %%
# cheking initial test accuracy
y_pred = model.predict(test_x)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(test_y,predictions)
accuracy
# Out:
# 0.8711694809255784

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
   
    ' learning_rate':[1,0.5,0.1,0.01,0.001],
    'max_depth': [3,5,10,20],
    'n_estimators':[10,50,100,200]
    
}

# %%
grid= GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid, verbose=3)

# %%
grid.fit(train_x,train_y)
# Out:
# C:\Users\Laptop\.conda\envs\vivek\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [21:46:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.858, total=   0.7s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [21:46:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.845, total=   0.7s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [21:46:04] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.853, total=   0.7s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [21:46:05] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.874, total=   2.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [21:46:07] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.860, total=   2.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [21:46:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.866, total=   2.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [21:46:11] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.878, total=   3.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [21:46:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.863, total=   3.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [21:46:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.871, total=   3.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [21:46:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.879, total=   6.9s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [21:46:28] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.865, total=   6.8s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [21:46:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.870, total=   6.4s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [21:46:41] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.866, total=   0.8s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [21:46:42] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.852, total=   0.8s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [21:46:43] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.860, total=   0.9s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [21:46:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.875, total=   2.8s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [21:46:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.863, total=   2.6s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [21:46:49] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.870, total=   2.7s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [21:46:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.876, total=   5.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [21:46:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.863, total=   5.2s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [21:47:02] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.870, total=   5.2s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [21:47:08] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.870, total=   9.7s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [21:47:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.863, total=   9.8s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [21:47:27] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.867, total=   9.9s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [21:47:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.872, total=   1.4s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [21:47:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.858, total=   1.4s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [21:47:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.862, total=   1.4s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [21:47:41] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.869, total=   5.0s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [21:47:46] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.856, total=   5.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [21:47:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.864, total=   5.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [21:47:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.865, total=   9.5s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [21:48:06] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.854, total=   9.6s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [21:48:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.861, total=   9.4s
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [21:48:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.859, total=  18.3s
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [21:48:43] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.853, total=  18.4s
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [21:49:02] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.856, total=  18.4s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [21:49:20] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=0.860, total=   2.3s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [21:49:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=0.850, total=   2.3s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [21:49:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=0.850, total=   2.3s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [21:49:27] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.860, total=   9.5s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [21:49:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.852, total=   9.8s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [21:49:46] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.854, total=   9.9s
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [21:49:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.855, total=  18.8s
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [21:50:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.850, total=  18.5s
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [21:50:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.853, total=  18.7s
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [21:50:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.855, total=  37.6s
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [21:51:30] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.846, total=  37.9s
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [21:52:08] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.852, total=  37.5s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [21:52:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=0.858, total=   0.7s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [21:52:46] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=0.845, total=   0.7s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [21:52:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=0.853, total=   0.7s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [21:52:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.874, total=   2.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [21:52:49] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.860, total=   2.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [21:52:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.866, total=   1.9s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [21:52:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.878, total=   3.5s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [21:52:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.863, total=   3.6s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [21:53:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.871, total=   3.5s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [21:53:04] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.879, total=   6.7s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [21:53:11] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.865, total=   6.7s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [21:53:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.870, total=   6.6s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [21:53:24] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=0.866, total=   0.9s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [21:53:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=0.852, total=   0.9s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [21:53:26] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=0.860, total=   0.9s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [21:53:27] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.875, total=   2.9s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [21:53:29] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.863, total=   2.7s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [21:53:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.870, total=   2.8s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [21:53:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.876, total=   5.2s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [21:53:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.863, total=   5.1s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [21:53:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.870, total=   5.2s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [21:53:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.870, total=  10.0s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [21:54:01] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.863, total=   9.8s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [21:54:10] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.867, total=   9.8s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [21:54:20] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=0.872, total=   1.4s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [21:54:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=0.858, total=   1.4s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [21:54:23] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=0.862, total=   1.4s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [21:54:24] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.869, total=   5.0s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [21:54:29] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.856, total=   5.0s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [21:54:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.864, total=   4.9s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [21:54:39] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.865, total=   9.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [21:54:48] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.854, total=   9.2s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [21:54:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.861, total=   9.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [21:55:07] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.859, total=  18.6s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [21:55:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.853, total=  19.2s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [21:55:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.856, total=  18.8s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [21:56:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=0.860, total=   2.3s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [21:56:06] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=0.850, total=   2.2s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [21:56:08] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# ...
# [22:14:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=200, score=0.863, total=   9.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200 .............
# [22:14:26] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=200, score=0.867, total=  10.0s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [22:14:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.872, total=   1.3s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [22:14:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.858, total=   1.3s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [22:14:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.862, total=   1.3s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [22:14:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.869, total=   4.9s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [22:14:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.856, total=   4.4s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [22:14:49] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.864, total=   4.4s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [22:14:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.865, total=   8.5s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [22:15:02] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.854, total=   8.7s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [22:15:11] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.861, total=   8.7s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [22:15:19] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.859, total=  16.4s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [22:15:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.853, total=  16.8s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [22:15:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.856, total=  16.6s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [22:16:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.860, total=   2.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [22:16:11] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.850, total=   2.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [22:16:13] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.850, total=   2.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [22:16:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.860, total=   8.9s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [22:16:24] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.852, total=   8.6s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [22:16:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.854, total=   9.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [22:16:42] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.855, total=  17.7s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [22:17:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.850, total=  18.0s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [22:17:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.853, total=  17.7s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [22:17:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.855, total=  36.8s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [22:18:12] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.846, total=  37.8s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [22:18:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.852, total=  37.7s
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed: 33.4min finished
# [22:19:28] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_con...
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              iid='warn', n_jobs=None,
#              param_grid={' learning_rate': [1, 0.5, 0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 10, 20],
#                          'n_estimators': [10, 50, 100, 200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# To  find the parameters givingmaximum accuracy
grid.best_params_
# Out:
# {' learning_rate': 1, 'max_depth': 3, 'n_estimators': 200}

# %%
# Create new model using the same parameters
new_model=XGBClassifier(learning_rate= 1, max_depth= 5, n_estimators= 50)
new_model.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=50, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred_new = new_model.predict(test_x)
predictions_new = [round(value) for value in y_pred_new]
accuracy_new = accuracy_score(test_y,predictions_new)
accuracy_new
# Out:
# 0.858036272670419
